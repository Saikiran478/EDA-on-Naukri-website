# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\saikiran\file1.csv")
df.drop(["Unnamed: 0"], inplace =True, axis = 1)

# %%
df
# Out:
#                Job_name                                               Role  \
# 0    Software Developer  Software Developer/Software Engineer(B.E,B.Tec...
# 1    Software Developer                                 Software Developer
# 2    Software Developer                                 Software Developer
# 3    Software Developer                                 Software Developer
# 4    Software Developer  MNC Hiring | Fresher | Software Developer | Pa...
# ..                  ...                                                ...
# 398       Data Engineer                                      Data Engineer
# 399       Data Engineer                                  Big Data Engineer
# 400       Data Engineer                                      Data Engineer
# 401       Data Engineer                                 Data Engineer- SAS
# 402       Data Engineer                                      Data Engineer
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403 entries, 0 to 402
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Job_name               403 non-null    object
#  1   Role                   403 non-null    object
#  2   Company                403 non-null    object
#  3   Minimum Experience     403 non-null    int64
#  4   Maximum Experience     403 non-null    int64
#  5   Location               403 non-null    object
#  6   Rating                 403 non-null    float64
#  7   Minimum Salary in LPA  403 non-null    float64
#  8   Maximum Salary in LPA  403 non-null    float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 28.5+ KB

# %%
df.isnull().sum()
# Out:
# Job_name                 0
# Role                     0
# Company                  0
# Minimum Experience       0
# Maximum Experience       0
# Location                 0
# Rating                   0
# Minimum Salary in LPA    0
# Maximum Salary in LPA    0
# dtype: int64

# %% [markdown]
# # Univariate Analysis

# %%
plt.hist(df["Minimum Salary in LPA"])
plt.show()

# %% [markdown]
# #### Most of the salary is less than 30

# %%
df.describe()
# Out:
#        Minimum Experience  Maximum Experience      Rating  \
# count          403.000000          403.000000  403.000000
# mean             3.593052            6.997519    3.763524
# std              2.544754            3.298197    0.569004
# min              0.000000            0.000000    1.000000
# 25%              2.000000            5.000000    3.600000
# 50%              3.000000            7.000000    3.800000
# 75%              5.000000            9.000000    4.000000
# max             20.000000           27.000000    5.000000
#
#        Minimum Salary in LPA  Maximum Salary in LPA
# count             403.000000             403.000000
# mean                9.140074              15.368610
# std                 8.335824              11.837498
# min                 0.050000               0.050000
# 25%                 3.250000               7.000000
# 50%                 7.000000              15.000000
# 75%                12.000000              20.000000
# ...

# %%
df["Job_name"].value_counts()
# Out:
# Fullstack Developer    78
# Back End Developer     74
# Data Analyst           55
# Software Developer     51
# Data Science           49
# Software Engineer      41
# Data Engineer          33
# Web Developer          22
# Name: Job_name, dtype: int64

# %%
x = sns.countplot(df["Job_name"])

for i in x.containers:
    x.bar_label(i)
plt.xlabel("Job Role")
plt.ylabel("Number of Jobs according to Job Role")
plt.xticks(rotation = 90)
plt.show()

x
for i in x.containers:
    x.bar_label(i)
# Out:
# C:\Users\saikiran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Distribution of Job Types

# %%
plt.figure(figsize = (20,5))
y = df["Location"].value_counts().plot(kind = "bar",color = "y")
for i in y.containers:
    y.bar_label(i)
plt.xlabel("cities")
plt.ylabel("Number of Jobs according to Job Role")
plt.show()

# %% [markdown]
# #### Cities and their count of job oppurtunities

# %%
df["Job_name"].value_counts().plot(kind = "pie",autopct = '%.2f', label = "")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Percentage share of the Jobs

# %%
df['Location'].value_counts()[df['Location'].value_counts() > 5]
# Out:
# Multiple Cities                73
# Bengaluru                      56
# Hyderabad                      52
# Hybrid - Multiple Cities       35
# Delhi / NCR                    30
# Pune                           24
# Remote                         20
# Chennai                        17
# Mumbai                         15
# Hybrid - Bengaluru             12
# Temp. WFH - Multiple Cities     7
# Hybrid - Hyderabad              7
# Ahmedabad                       6
# Hybrid - Delhi / NCR            6
# Name: Location, dtype: int64

# %%
df['Location'].value_counts()[df['Location'].value_counts() > 5].plot(kind = "bar",color = "g")
plt.xlabel("Location")
plt.ylabel("Number of Jobs at a location")
plt.show()

# %% [markdown]
# #### The  cities which are having more 5 job oppurtunities and Bengaluru,Hyderabad and Delhi are having the most number of jobs

# %%
plt.figure(figsize = (10,10))
df["Location"].value_counts()[df['Location'].value_counts() > 5].plot(kind = "pie",autopct = '%.2f', label = "")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.04), ncol=4)
plt.figure()
plt.show()

# %% [markdown]
# #### percentages of the cities for job oppurtunities

# %%
sns.distplot(df["Rating"])
# Out:
# C:\Users\saikiran\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Rating', ylabel='Density'>

# %% [markdown]
# #### Distribution of the rating where most of the companies have 3.5 to 4.2

# %%
sns.boxplot(df["Minimum Salary in LPA"])
# Out:
# C:\Users\saikiran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Minimum Salary in LPA'>

# %% [markdown]
# #### most of the salaries are in the range of 3.25 to 12 lpa also it is the inter quartile range

# %%
a = df.groupby("Job_name")
a.first()
# Out:
#                                                                   Role  \
# Job_name
# Back End Developer                                  Back End Developer
# Data Analyst                                       Senior Data Analyst
# Data Engineer                                            Data Engineer
# Data Science                                          SSE-Data Science
# Fullstack Developer                                Fullstack Developer
# Software Developer   Software Developer/Software Engineer(B.E,B.Tec...
# Software Engineer                                    Software Engineer
# Web Developer                                            Web Developer
#
#                                                 Company  Minimum Experience  \
# Job_name
# Back End Developer   Enthralltech Private Limited, Pune                   5
# Data Analyst                                   Liventus                   3
# Data Engineer                             Tech Mahindra                   4
# ...

# %%
sns.jointplot(df["Minimum Experience"],df["Minimum Salary in LPA"])
# Out:
# C:\Users\saikiran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Scatter plot shows the mostly companies need 0 - 10 years of experience and giving the salaries of  3-30 lpa

# %%
sns.jointplot(df["Rating"],df["Minimum Salary in LPA"])
# Out:
# C:\Users\saikiran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### graph shows that rating and salary are not related

# %%
sns.barplot(df["Job_name"],df["Maximum Salary in LPA"])
plt.xticks(rotation = 90)
# Out:
# C:\Users\saikiran\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'Software Developer'),
#   Text(1, 0, 'Data Science'),
#   Text(2, 0, 'Data Analyst'),
#   Text(3, 0, 'Software Engineer'),
#   Text(4, 0, 'Fullstack Developer'),
#   Text(5, 0, 'Web Developer'),
#   Text(6, 0, 'Back End Developer'),
#   Text(7, 0, 'Data Engineer')])

# %% [markdown]
# #### The type of jobs which are having the higher salary

# %%
#sns.barplot(df["Maximum Salary in LPA"])

# %%
#sns.barplot(df["Location"].value_counts()[df['Location'].value_counts() > 5],df["Maximum Salary in LPA"])

# %%
avg_sal = df.groupby(["Job_name"],as_index =False)["Minimum Salary in LPA"].mean().sort_values(by = "Minimum Salary in LPA", ascending = False)
a = sns.barplot(data = avg_sal,x  = avg_sal["Job_name"], y = avg_sal["Minimum Salary in LPA"])
plt.xlabel("Job Role")
plt.ylabel("Average Salary for Job Type")
plt.xticks(rotation = 90)
for i in a.containers:
    a.bar_label(i)
plt.show()

# %% [markdown]
# #### The Data Science are getting higher salary and web and software developer are getting lower salry package according to this data

# %%
plt.figure(figsize = (8,6))
avg_rating = df.groupby(["Job_name"],as_index =False)["Rating"].mean().sort_values(by ="Rating")
a1 = sns.barplot(data = avg_rating,x  = avg_rating["Job_name"], y = avg_rating["Rating"])
plt.xlabel("Job Role")
plt.ylabel("Average Rating for Job Type")
plt.xticks(rotation = 90)
for i in a1.containers:
    a1.bar_label(i)
plt.show()

# %% [markdown]
# #### Software developer, Data science jobs are having more rating and web developer and full stack developer is having less rating

# %%
l = df['Location'].value_counts()[df['Location'].value_counts() > 5]
l
# Out:
# Multiple Cities                73
# Bengaluru                      56
# Hyderabad                      52
# Hybrid - Multiple Cities       35
# Delhi / NCR                    30
# Pune                           24
# Remote                         20
# Chennai                        17
# Mumbai                         15
# Hybrid - Bengaluru             12
# Temp. WFH - Multiple Cities     7
# Hybrid - Hyderabad              7
# Ahmedabad                       6
# Hybrid - Delhi / NCR            6
# Name: Location, dtype: int64

# %%
plt.figure(figsize = (8,6))
avg_rating = df.groupby(["Job_name"],as_index =False)["Minimum Experience"].mean().sort_values(by ="Minimum Experience")
a1 = sns.barplot(data = avg_rating,x  = avg_rating["Job_name"], y = avg_rating["Minimum Experience"])
plt.xlabel("Job Role")
plt.ylabel("Average Experience for Job Type")
plt.xticks(rotation = 90)
for i in a1.containers:
    a1.bar_label(i)
plt.show()

# %% [markdown]
# #### Experience needed for data engineer is high and experience for software jobs is low

# %%
plt.figure(figsize = (20,20))
sns.heatmap(pd.crosstab(df["Location"],df["Job_name"]))
plt.show()

# %%
l1 = df.groupby(["Location"])
df_la = l1.get_group("Ahmedabad")

# %%
df_la
# Out:
#                 Job_name                 Role           Company  \
# 105         Data Analyst  Junior Data Analyst     Ohm Analytics
# 194    Software Engineer    Software Engineer     Tech Mahindra
# 216  Fullstack Developer  Fullstack Developer  Parul University
# 231  Fullstack Developer  Fullstack Developer         Aurionpro
# 232  Fullstack Developer  Fullstack Developer          EVC Labs
# 234  Fullstack Developer  Fullstack Developer            Inzint
#
#      Minimum Experience  Maximum Experience   Location  Rating  \
# 105                   0                   5  Ahmedabad     3.8
# 194                   5                   7  Ahmedabad     3.7
# 216                   2                   4  Ahmedabad     3.4
# 231                   3                   6  Ahmedabad     3.9
# 232                   2                   5  Ahmedabad     2.8
# 234                   1                   4  Ahmedabad     4.2
#
#      Minimum Salary in LPA  Maximum Salary in LPA
# ...

# %%
df_lb = l1.get_group("Bengaluru")
df_lb.head()
# Out:
#               Job_name                                               Role  \
# 24  Software Developer      Software Developer with PAF and Questionnaire
# 27  Software Developer                                 Software Developer
# 34  Software Developer  Software Developer (Power Platform) - Uganda -...
# 35  Software Developer                          Python Software Developer
# 36  Software Developer                          Software Developer Intern
#
#                       Company  Minimum Experience  Maximum Experience  \
# 24       Quality Naukri(ieil)                   4                   9
# 27           Amity University                   5                   9
# 34        Trigyn Technologies                   4                   9
# 35                  Valuelabs                   2                   4
# 36  Premium Learnings Systems                   4                   7
#
#      Location  Rating  Minimum Salary in LPA  Maximum Salary in LPA
# ...

# %%
df_lc = l1.get_group("Chennai")
df_lc.head()
# Out:
#          Job_name                                Role              Company  \
# 98   Data Science  Data Scientist || Immediate Joiner             Sun Life
# 131  Data Analyst      Hiring - Data Research Analyst          Morningstar
# 138  Data Analyst                        Data Analyst           H K Jewels
# 142  Data Analyst                        Data Analyst  K12 Techno Services
# 151  Data Analyst       Data Analyst || Stanza Living        Stanza Living
#
#      Minimum Experience  Maximum Experience Location  Rating  \
# 98                    2                   6  Chennai     4.4
# 131                   0                   4  Chennai     4.2
# 138                   6                   7  Chennai     3.6
# 142                   5                  10  Chennai     3.1
# 151                   3                   5  Chennai     3.0
#
#      Minimum Salary in LPA  Maximum Salary in LPA
# 98                    20.0                   30.0
# ...

# %%
df_ld= l1.get_group("Delhi / NCR")
df_ld.head()
# Out:
#               Job_name                                    Role  \
# 29  Software Developer                      Software Developer
# 32  Software Developer     Junior Software Developer (c#/.net)
# 33  Software Developer  Urgent Opening For Software Developers
# 42  Software Developer                      Software Developer
# 55        Data Science          Senior Engineer - Data Science
#
#                                    Company  Minimum Experience  \
# 29                            SLK Software                   1
# 32                    Proseon Technologies                   3
# 33         Manupatra Information Solutions                   3
# 42                        Brightsun Travel                   4
# 55  CAMBRIDGE TECHNOLOGY ENTERPRISES (CTE)                   4
#
#     Maximum Experience     Location  Rating  Minimum Salary in LPA  \
# 29                   5  Delhi / NCR     3.7                   7.00
# 32                   4  Delhi / NCR     4.8                   1.75
# ...

# %%
df_hb= l1.get_group("Hybrid - Bengaluru")
df_hb.head()
# Out:
#                Job_name                                          Role  \
# 19   Software Developer                           Software  Developer
# 80         Data Science                                Data Scientist
# 94         Data Science     Hiring For Data Analyst @ Medanta Gurgaon
# 148        Data Analyst  Data Scientist/ Senior Business Data Analyst
# 167   Software Engineer      Software Engineer - Freshers Bulk hiring
#
#                      Company  Minimum Experience  Maximum Experience  \
# 19                 Capgemini                   6                  10
# 80         Tata Technologies                   2                   7
# 94                   Medanta                   4                   8
# 148        Lufthansa Technik                   5                   8
# 167  Aficionado Technologies                   2                   5
#
#                Location  Rating  Minimum Salary in LPA  Maximum Salary in LPA
# ...

# %%
df_hd= l1.get_group("Hybrid - Delhi / NCR")
df_hd
# Out:
#                Job_name                 Role  \
# 15   Software Developer   Software Developer
# 103        Data Analyst         Data Analyst
# 136        Data Analyst  Senior Data Analyst
# 286       Web Developer        Web Developer
# 296  Back End Developer   Back End Developer
# 387       Data Engineer        Data Engineer
#
#                                 Company  Minimum Experience  \
# 15             Softtact Innovations Llp                   0
# 103                        Wilco Source                   3
# 136                 Saarthee Technology                   1
# 286                  Thakur Publication                   3
# 296  Enthralltech Private Limited, Pune                   5
# 387                       Tech Mahindra                   5
#
#      Maximum Experience              Location  Rating  Minimum Salary in LPA  \
# 15                    1  Hybrid - Delhi / NCR     2.0                    1.0
# ...

# %%
df_hh= l1.get_group("Hybrid - Hyderabad")
df_hh
# Out:
#                 Job_name                                               Role  \
# 244  Fullstack Developer                Java Full Stack Developer - Angular
# 253  Fullstack Developer                           java Fullstack Developer
# 324   Back End Developer  Senior Front End Developer @ Heritage Foods Lt...
# 343   Back End Developer             Sr AWS (Backend) Developer For Top MNC
# 365   Back End Developer                             Senior Azure Developer
# 367   Back End Developer                AWS Developer (Backend) For Top MNC
# 370        Data Engineer                                      Data Engineer
#
#                 Company  Minimum Experience  Maximum Experience  \
# 244       ACS Solutions                   4                   9
# 253  RLE INTERNATIONAL                    6                  11
# 324      Heritage Foods                   1                   3
# 343    LRR Technologies                   8                  10
# ...

# %%
df_hm= l1.get_group("Hybrid - Multiple Cities")
df_hm.head()
# Out:
#               Job_name                                               Role  \
# 4   Software Developer  MNC Hiring | Fresher | Software Developer | Pa...
# 7   Software Developer  Software Engineer, developer / Programmer, 202...
# 10  Software Developer                                 Software Developer
# 23  Software Developer              Siemens Automation Software developer
# 72        Data Science  Permanent Opportunity - Data Scientist(Snaplog...
#
#               Company  Minimum Experience  Maximum Experience  \
# 4         Campus Marg                   0                   2
# 7   Creative Hands HR                   0                   2
# 10  Teamlease Digital                   4                   9
# 23    Ways Automation                   5                   8
# 72           Deloitte                   3                   8
#
#                     Location  Rating  Minimum Salary in LPA  \
# 4   Hybrid - Multiple Cities     3.9                    6.0
# ...

# %%
df_lh= l1.get_group("Hyderabad")
df_lh.head()
# Out:
#               Job_name                Role                           Company  \
# 1   Software Developer  Software Developer          Soulfly Aviation Academy
# 6   Software Developer  Software Developer                 Teamlease Digital
# 16  Software Developer  Software Developer          Epiance Software Pvt Ltd
# 17  Software Developer  Software Developer  Tecnics Integration Technologies
# 25  Software Developer  Software Developer                   Eappsproaccount
#
#     Minimum Experience  Maximum Experience   Location  Rating  \
# 1                    0                   3  Hyderabad     3.9
# 6                    1                   3  Hyderabad     3.9
# 16                   0                   1  Hyderabad     3.2
# 17                   6                   7  Hyderabad     3.7
# 25                   3                   6  Hyderabad     4.2
#
#     Minimum Salary in LPA  Maximum Salary in LPA
# 1                    3.00                    8.0
# ...

# %%
df_lm= l1.get_group("Multiple Cities")
df_lm.head()
# Out:
#               Job_name                                               Role  \
# 0   Software Developer  Software Developer/Software Engineer(B.E,B.Tec...
# 2   Software Developer                                 Software Developer
# 9   Software Developer                          Python Software Developer
# 11  Software Developer                                 Software Developer
# 12  Software Developer                                 Software Developer
#
#                      Company  Minimum Experience  Maximum Experience  \
# 0             jj Consultancy                   0                   5
# 2   Soulfly Aviation Academy                   0                   0
# 9           Learner Landmark                   0                   4
# 11                     Aveva                   4                   7
# 12                 Algogenix                   0                   5
#
#            Location  Rating  Minimum Salary in LPA  Maximum Salary in LPA
# ...

# %%
df_m= l1.get_group("Mumbai")
df_m.head()
# Out:
#                Job_name                           Role  \
# 45   Software Developer             Software Developer
# 54         Data Science  Senior Data Science Associate
# 57         Data Science          Data Science Engineer
# 61         Data Science           Data Science Trainer
# 114        Data Analyst                   Data Analyst
#
#                                     Company  Minimum Experience  \
# 45                                     MRCC                   5
# 54   CAMBRIDGE TECHNOLOGY ENTERPRISES (CTE)                  10
# 57                    Vservice It Solutions                   2
# 61                Aedifico Skill Innovation                   4
# 114                 Selective Global Search                   5
#
#      Maximum Experience Location  Rating  Minimum Salary in LPA  \
# 45                    8   Mumbai     3.3                    7.0
# 54                   12   Mumbai     4.3                    6.0
# ...

# %%
df_lp= l1.get_group("Pune")
df_lp.head()
# Out:
#               Job_name                                               Role  \
# 30  Software Developer              Senior Software Developer - 4G/5G/LTE
# 31  Software Developer                             Jr. Software Developer
# 38  Software Developer             Senior Software Developer (MEAN Stack)
# 48  Software Developer  Opportunity For Software Developer Windows tun...
# 50  Software Developer                               Data Science Trainer
#
#                   Company  Minimum Experience  Maximum Experience Location  \
# 30            ACL Digital                   5                   9     Pune
# 31      Le Logix Software                   0                   3     Pune
# 38               Softobiz                   2                   7     Pune
# 48           Hinduja Tech                   2                   4     Pune
# 50  Zeominds It Solutions                   2                   3     Pune
#
#     Rating  Minimum Salary in LPA  Maximum Salary in LPA
# ...

# %%
df_lr= l1.get_group("Remote")
df_lr.head()
# Out:
#                Job_name                                               Role  \
# 41   Software Developer                                 Software Developer
# 101        Data Analyst  Senior Process Executive-Content Analysis/Data...
# 147        Data Analyst        Java Full Stack Developer and Data Analysts
# 164   Software Engineer                        Software Engineer (JLPT N2)
# 185   Software Engineer       Software Engineers-.NET MVC (Work From Home)
#
#                                 Company  Minimum Experience  \
# 41   Elpis It Solutions Private Limited                   3
# 101                           Cognizant                   5
# 147                  Prowess Publishing                   5
# 164                   Persolkelly India                   5
# 185               Ingenium Technologies                   3
#
#      Maximum Experience Location  Rating  Minimum Salary in LPA  \
# 41                    8   Remote     3.7                    4.0
# ...

# %%
df_lt= l1.get_group("Temp. WFH - Multiple Cities")
df_lt
# Out:
#                 Job_name                                               Role  \
# 3     Software Developer                                 Software Developer
# 5     Software Developer  Software Engineer, developer / Programmer, 202...
# 21    Software Developer                             Software Developer paf
# 65          Data Science                          Data Scientist Consultant
# 112         Data Analyst                                Senior Data Analyst
# 259  Fullstack Developer                     Java Full Stack/Java Developer
# 363   Back End Developer  Backend developer with C++,Python &  API_Immed...
#
#                   Company  Minimum Experience  Maximum Experience  \
# 3    AFR India Connexions                   0                   5
# 5       Creative Hands HR                   0                   1
# 21   Quality Naukri(ieil)                   4                   8
# 65         Aarons Visions                   5                  10
# ...

# %%
l
# Out:
# Multiple Cities                73
# Bengaluru                      56
# Hyderabad                      52
# Hybrid - Multiple Cities       35
# Delhi / NCR                    30
# Pune                           24
# Remote                         20
# Chennai                        17
# Mumbai                         15
# Hybrid - Bengaluru             12
# Temp. WFH - Multiple Cities     7
# Hybrid - Hyderabad              7
# Ahmedabad                       6
# Hybrid - Delhi / NCR            6
# Name: Location, dtype: int64

# %%
all_df = (df_la,df_lb,df_lc,df_ld,df_hb,df_hd,df_hd,df_hm,df_lh,df_lm,df_m,df_lp,df_lr,df_lt)
add_df = pd.concat(all_df)
add_df.head()
# Out:
#                 Job_name                 Role           Company  \
# 105         Data Analyst  Junior Data Analyst     Ohm Analytics
# 194    Software Engineer    Software Engineer     Tech Mahindra
# 216  Fullstack Developer  Fullstack Developer  Parul University
# 231  Fullstack Developer  Fullstack Developer         Aurionpro
# 232  Fullstack Developer  Fullstack Developer          EVC Labs
#
#      Minimum Experience  Maximum Experience   Location  Rating  \
# 105                   0                   5  Ahmedabad     3.8
# 194                   5                   7  Ahmedabad     3.7
# 216                   2                   4  Ahmedabad     3.4
# 231                   3                   6  Ahmedabad     3.9
# 232                   2                   5  Ahmedabad     2.8
#
#      Minimum Salary in LPA  Maximum Salary in LPA
# 105                    1.5                   3.50
# 194                    4.0                   9.00
# ...

# %%
plt.figure(figsize = (10,8))
sns.heatmap(pd.crosstab(add_df["Location"],add_df["Job_name"]))
plt.show()

# %% [markdown]
# #### heatmap shows the count of jobs at a particular location

# %%
plt.figure(figsize = (10,6))
avg_rating = add_df.groupby(["Location"],as_index =False)["Minimum Salary in LPA"].mean().sort_values(by ="Minimum Salary in LPA")
a1 = sns.barplot(data = avg_rating,x  = avg_rating["Location"], y = avg_rating["Minimum Salary in LPA"])
plt.xlabel("Cities")
plt.ylabel("Average Salaries for Cities")
plt.xticks(rotation = 90)
for i in a1.containers:
    a1.bar_label(i)
plt.show()

# %% [markdown]
# #### Hyderabad, Delhi, chennai people are getting the average salaries of more than 9 lpa

# %%
plt.figure(figsize = (15,8))
sns.boxplot(x = df["Job_name"], y = df["Minimum Salary in LPA"])
plt.show()

# %% [markdown]
# #### boxplot shows the frequency of salaries according to the jobs

# %%
plt.figure(figsize = (15,5),dpi = 100)
sns.catplot(data = add_df , col = "Location", x = "Job_name",kind = "count")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### The catplot shows the count of job roles according to the cities

# %%
sns.pairplot(df)

# %% [markdown]
# #### pairplot of this data
