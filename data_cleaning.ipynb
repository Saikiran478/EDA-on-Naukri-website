# %%
import numpy as np
import pandas as pd
df = pd.read_csv(r"D:\data_frame_rescrap1.csv")
df
# Out:
#       Unnamed: 0            Job_name  \
# 0              0  software-developer
# 1              1  software-developer
# 2              2  software-developer
# 3              3  software-developer
# 4              4  software-developer
# ...          ...                 ...
# 6066        6066       data-engineer
# 6067        6067       data-engineer
# 6068        6068       data-engineer
# 6069        6069       data-engineer
# 6070        6070       data-engineer
#
#                                                    Role  \
# 0     Software Developer and Business Process Developer
# 1                       Software Developer and Designer
# 2                            Software Developer/Trainee
# 3          Data Engineering - Senior Software Developer
# 4                 Senior Developer Department: Software
# ...                                                 ...
# 6066                                      Data engineer
# 6067                                      Data Engineer
# ...

# %%
df1 = df[df['Salary'] != 'Not disclosed']
df1
# Out:
#       Unnamed: 0            Job_name  \
# 5              5  software-developer
# 8              8  software-developer
# 10            10  software-developer
# 16            16  software-developer
# 17            17  software-developer
# ...          ...                 ...
# 5983        5983       data-engineer
# 6014        6014       data-engineer
# 6017        6017       data-engineer
# 6019        6019       data-engineer
# 6034        6034       data-engineer
#
#                                                    Role  \
# 5     Software Developer/Software Engineer(B.E,B.Tec...
# 8                                    Software Developer
# 10                                   Software Developer
# 16                                   Software Developer
# 17    MNC Hiring | Fresher | Software Developer | Pa...
# ...                                                 ...
# 5983                                      DATA Engineer
# 6014                                Azure Data Engineer
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 744 entries, 5 to 6034
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      744 non-null    int64
#  1   Job_name        744 non-null    object
#  2   Role            744 non-null    object
#  3   Company         744 non-null    object
#  4   Min_Experience  743 non-null    float64
#  5   Max_Experiece   743 non-null    float64
#  6   Salary          744 non-null    object
#  7   Location        744 non-null    object
#  8   Rating          324 non-null    float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 58.1+ KB

# %%
df1[df1.isnull().sum(axis = 1) == 0]
# Out:
#       Unnamed: 0            Job_name  \
# 5              5  software-developer
# 37            37  software-developer
# 50            50  software-developer
# 58            58  software-developer
# 96            96  software-developer
# ...          ...                 ...
# 5811        5811       data-engineer
# 5846        5846       data-engineer
# 5895        5895       data-engineer
# 5905        5905       data-engineer
# 5954        5954       data-engineer
#
#                                                    Role  \
# 5     Software Developer/Software Engineer(B.E,B.Tec...
# 37                                   Software Developer
# 50                                   Software Developer
# 58                            Junior Software developer
# 96                                   Software Developer
# ...                                                 ...
# 5811                                      Data Engineer
# 5846                                  Big Data Engineer
# ...

# %%
df1.describe(include = "float")
# Out:
#        Min_Experience  Max_Experiece      Rating
# count      743.000000     743.000000  324.000000
# mean         3.499327       6.987887    3.766049
# std          2.480042       3.276744    0.633694
# min          0.000000       0.000000    1.000000
# 25%          2.000000       5.000000    3.600000
# 50%          3.000000       7.000000    3.800000
# 75%          5.000000       9.000000    4.200000
# max         20.000000      27.000000    5.000000

# %%
a = df1.groupby("Job_name")
a.first()
# Out:
#                      Unnamed: 0  \
# Job_name
# back-end-developer         4553
# data-analysis              1525
# data-engineer              5318
# data-science                759
# fullstack-developer        3036
# software-developer            5
# software-engineer          2281
# web-developer              3797
#
#                                                                   Role  \
# Job_name
# back-end-developer                                  Back End Developer
# data-analysis                                      Senior Data Analyst
# data-engineer                                            Data Engineer
# data-science                                          SSE-Data Science
# fullstack-developer                                Fullstack Developer
# software-developer   Software Developer/Software Engineer(B.E,B.Tec...
# software-engineer                                    Software Engineer
# web-developer                                            Web Developer
#
# ...

# %%
d_sd = a.get_group("software-developer")
d_sd
# Out:
#      Unnamed: 0            Job_name  \
# 5             5  software-developer
# 8             8  software-developer
# 10           10  software-developer
# 16           16  software-developer
# 17           17  software-developer
# ..          ...                 ...
# 721         721  software-developer
# 727         727  software-developer
# 733         733  software-developer
# 753         753  software-developer
# 758         758  software-developer
#
#                                                   Role  \
# 5    Software Developer/Software Engineer(B.E,B.Tec...
# 8                                   Software Developer
# 10                                  Software Developer
# 16                                  Software Developer
# 17   MNC Hiring | Fresher | Software Developer | Pa...
# ..                                                 ...
# 721  Openings For Senior Software Developer For Top...
# 727  Dot Net Core with Azure - Senior Software Deve...
# ...

# %%
sd = d_sd[d_sd.isnull().sum(axis = 1) == 0]
sd                                           # df of group software developer
# Out:
#      Unnamed: 0            Job_name  \
# 5             5  software-developer
# 37           37  software-developer
# 50           50  software-developer
# 58           58  software-developer
# 96           96  software-developer
# 140         140  software-developer
# 141         141  software-developer
# 166         166  software-developer
# 182         182  software-developer
# 185         185  software-developer
# 189         189  software-developer
# 190         190  software-developer
# 191         191  software-developer
# 200         200  software-developer
# 232         232  software-developer
# 242         242  software-developer
# 309         309  software-developer
# 322         322  software-developer
# 323         323  software-developer
# 325         325  software-developer
# 411         411  software-developer
# 424         424  software-developer
# 435         435  software-developer
# 436         436  software-developer
# 445         445  software-developer
# ...

# %%
mean_sd = sd["Rating"].mean()
mean_sd                             # mean of rating in software developer df
# Out:
# 3.8682926829268314

# %%
sd1 = d_sd[d_sd.isnull().sum(axis = 1) == 1]
sd1                                            # DF which are having nan values in rating column
# Out:
#      Unnamed: 0            Job_name  \
# 8             8  software-developer
# 10           10  software-developer
# 16           16  software-developer
# 17           17  software-developer
# 20           20  software-developer
# ..          ...                 ...
# 703         703  software-developer
# 719         719  software-developer
# 721         721  software-developer
# 727         727  software-developer
# 733         733  software-developer
#
#                                                   Role  \
# 8                                   Software Developer
# 10                                  Software Developer
# 16                                  Software Developer
# 17   MNC Hiring | Fresher | Software Developer | Pa...
# 20   Software Engineer, developer / Programmer, 202...
# ..                                                 ...
# 703                                 Software Developer
# 719                                 Software Developer
# ...

# %%
sd_1 = sd1.head(10)                             # 10 rows from nan valued DF

# %%
add = (sd,sd_1)
r = pd.concat(add)
df_sd = r.sort_index()                          # adding 10 rows from nan valued DF and non null DF

# %%
df_sd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 5 to 758
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      51 non-null     int64
#  1   Job_name        51 non-null     object
#  2   Role            51 non-null     object
#  3   Company         51 non-null     object
#  4   Min_Experience  51 non-null     float64
#  5   Max_Experiece   51 non-null     float64
#  6   Salary          51 non-null     object
#  7   Location        51 non-null     object
#  8   Rating          41 non-null     float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 4.0+ KB

# %%
df_sd['Rating'].fillna(value=mean_sd, inplace=True)                           # fill the 10 rows with mean of rating

# %%
df_sd["Job_name"] = "Software Developer"
df_sd
# Out:
#      Unnamed: 0            Job_name  \
# 5             5  Software Developer
# 8             8  Software Developer
# 10           10  Software Developer
# 16           16  Software Developer
# 17           17  Software Developer
# 20           20  Software Developer
# 21           21  Software Developer
# 22           22  Software Developer
# 24           24  Software Developer
# 25           25  Software Developer
# 27           27  Software Developer
# 37           37  Software Developer
# 50           50  Software Developer
# 58           58  Software Developer
# 96           96  Software Developer
# 140         140  Software Developer
# 141         141  Software Developer
# 166         166  Software Developer
# 182         182  Software Developer
# 185         185  Software Developer
# 189         189  Software Developer
# 190         190  Software Developer
# 191         191  Software Developer
# 200         200  Software Developer
# 232         232  Software Developer
# ...

# %%
d_ds = a.get_group("data-science")
ds = d_ds[d_ds.isnull().sum(axis = 1) == 0]
mean_ds = ds["Rating"].mean()
ds1 = d_ds[d_ds.isnull().sum(axis = 1) == 1]
ds_1 = ds1.head(10)
add1 = (ds,ds_1)
r1 = pd.concat(add1)
df_ds = r1.sort_index()
df_ds['Rating'].fillna(value=mean_ds, inplace=True)            # repeating same from other grouped Job_name

# %%
df_ds["Job_name"] = "Data Science"
df_ds
# Out:
#       Unnamed: 0      Job_name  \
# 759          759  Data Science
# 781          781  Data Science
# 791          791  Data Science
# 797          797  Data Science
# 805          805  Data Science
# 821          821  Data Science
# 864          864  Data Science
# 868          868  Data Science
# 872          872  Data Science
# 873          873  Data Science
# 903          903  Data Science
# 908          908  Data Science
# 926          926  Data Science
# 932          932  Data Science
# 936          936  Data Science
# 952          952  Data Science
# 958          958  Data Science
# 959          959  Data Science
# 965          965  Data Science
# 990          990  Data Science
# 992          992  Data Science
# 996          996  Data Science
# 997          997  Data Science
# 1009        1009  Data Science
# 1010        1010  Data Science
# 1026        1026  Data Science
# 1036        1036  Data Science
# 1060        1060  Data Science
# 1086        1086  Data Science
# ...

# %%
d_da = a.get_group("data-analysis")
da = d_da[d_da.isnull().sum(axis = 1) == 0]
mean_da = da["Rating"].mean()
da1 = d_da[d_da.isnull().sum(axis = 1) == 1]
da_1 = da1.head(10)
add2 = (da,da_1)
r2 = pd.concat(add2)
df_da = r2.sort_index()
df_da['Rating'].fillna(value=mean_da, inplace=True)
df_da["Job_name"] = "Data Analyst"

# %%
df_da
# Out:
#       Unnamed: 0      Job_name  \
# 1525        1525  Data Analyst
# 1528        1528  Data Analyst
# 1530        1530  Data Analyst
# 1534        1534  Data Analyst
# 1535        1535  Data Analyst
# 1544        1544  Data Analyst
# 1553        1553  Data Analyst
# 1554        1554  Data Analyst
# 1561        1561  Data Analyst
# 1562        1562  Data Analyst
# 1578        1578  Data Analyst
# 1579        1579  Data Analyst
# 1581        1581  Data Analyst
# 1582        1582  Data Analyst
# 1618        1618  Data Analyst
# 1619        1619  Data Analyst
# 1629        1629  Data Analyst
# 1633        1633  Data Analyst
# 1646        1646  Data Analyst
# 1649        1649  Data Analyst
# 1659        1659  Data Analyst
# 1660        1660  Data Analyst
# 1678        1678  Data Analyst
# 1680        1680  Data Analyst
# 1689        1689  Data Analyst
# 1690        1690  Data Analyst
# 1693        1693  Data Analyst
# 1697        1697  Data Analyst
# 1710        1710  Data Analyst
# ...

# %%
d_se = a.get_group("software-engineer")
se = d_se[d_se.isnull().sum(axis = 1) == 0]
mean_se = se["Rating"].mean()
se1 = d_se[d_se.isnull().sum(axis = 1) == 1]
se_1 = se1.head(10)
add3 = (se,se_1)
r3 = pd.concat(add3)
df_se = r3.sort_index()
df_se['Rating'].fillna(value=mean_se, inplace=True)
df_se["Job_name"] = "Software Engineer"

# %%
df_se
# Out:
#       Unnamed: 0           Job_name  \
# 2281        2281  Software Engineer
# 2285        2285  Software Engineer
# 2302        2302  Software Engineer
# 2308        2308  Software Engineer
# 2310        2310  Software Engineer
# 2321        2321  Software Engineer
# 2322        2322  Software Engineer
# 2349        2349  Software Engineer
# 2358        2358  Software Engineer
# 2359        2359  Software Engineer
# 2360        2360  Software Engineer
# 2361        2361  Software Engineer
# 2372        2372  Software Engineer
# 2375        2375  Software Engineer
# 2376        2376  Software Engineer
# 2377        2377  Software Engineer
# 2381        2381  Software Engineer
# 2402        2402  Software Engineer
# 2414        2414  Software Engineer
# 2418        2418  Software Engineer
# 2424        2424  Software Engineer
# 2426        2426  Software Engineer
# 2436        2436  Software Engineer
# 2437        2437  Software Engineer
# 2442        2442  Software Engineer
# ...

# %%
d_fd = a.get_group("fullstack-developer")
fd = d_fd[d_fd.isnull().sum(axis = 1) == 0]
mean_fd = fd["Rating"].mean()
fd1 = d_fd[d_fd.isnull().sum(axis = 1) == 1]
fd_1 = fd1.head(10)
add4 = (fd,fd_1)
r4 = pd.concat(add4)
df_fd = r4.sort_index()
df_fd['Rating'].fillna(value=mean_fd, inplace=True)
df_fd["Job_name"] = "Fullstack Developer"
df_fd
# Out:
#       Unnamed: 0             Job_name  \
# 3036        3036  Fullstack Developer
# 3037        3037  Fullstack Developer
# 3038        3038  Fullstack Developer
# 3039        3039  Fullstack Developer
# 3040        3040  Fullstack Developer
# ...          ...                  ...
# 3742        3742  Fullstack Developer
# 3743        3743  Fullstack Developer
# 3744        3744  Fullstack Developer
# 3748        3748  Fullstack Developer
# 3789        3789  Fullstack Developer
#
#                                                    Role  \
# 3036                                Fullstack Developer
# 3037  Fullstack Developer (Working Abroad For Expats...
# 3038                      Fullstack Developer & Trainer
# 3039                                Fullstack Developer
# 3040                                Fullstack Developer
# ...                                                 ...
# 3742  Java Full Stack Developer // Wipro (C2H) // Hy...
# ...

# %%
d_wd = a.get_group("web-developer")
wd = d_wd[d_wd.isnull().sum(axis = 1) == 0]
mean_wd = wd["Rating"].mean()
wd1 = d_wd[d_wd.isnull().sum(axis = 1) == 1]
wd_1 = wd1.head(10)
add5 = (wd,wd_1)
r5 = pd.concat(add5)
df_wd = r5.sort_index()
df_wd['Rating'].fillna(value=mean_wd, inplace=True)
df_wd["Job_name"] = "Web Developer"
df_wd
# Out:
#       Unnamed: 0       Job_name                                   Role  \
# 3797        3797  Web Developer                          Web Developer
# 3892        3892  Web Developer         Web Developer - Work from Home
# 3893        3893  Web Developer                          Web Developer
# 3896        3896  Web Developer                          Web Developer
# 3899        3899  Web Developer                          Web Developer
# 3900        3900  Web Developer                          Web Developer
# 3901        3901  Web Developer              Opening For Web Developer
# 3903        3903  Web Developer                          Web Developer
# 3906        3906  Web Developer                          Web Developer
# 3908        3908  Web Developer                          Web Developer
# 3913        3913  Web Developer                          Web Developer
# 3915        3915  Web Developer      Web Developer - Dehradun Location
# ...

# %%
d_bd = a.get_group("back-end-developer")
bd = d_bd[d_bd.isnull().sum(axis = 1) == 0]
mean_bd = bd["Rating"].mean()
bd1 = d_bd[d_bd.isnull().sum(axis = 1) == 1]
bd_1 = bd1.head(10)
add6 = (bd,bd_1)
r6 = pd.concat(add6)
df_bd = r6.sort_index()
df_bd['Rating'].fillna(value=mean_bd, inplace=True)
df_bd["Job_name"] = "Back End Developer"
df_bd
# Out:
#       Unnamed: 0            Job_name  \
# 4553        4553  Back End Developer
# 4554        4554  Back End Developer
# 4556        4556  Back End Developer
# 4559        4559  Back End Developer
# 4561        4561  Back End Developer
# ...          ...                 ...
# 5213        5213  Back End Developer
# 5243        5243  Back End Developer
# 5253        5253  Back End Developer
# 5272        5272  Back End Developer
# 5276        5276  Back End Developer
#
#                                                    Role  \
# 4553                                 Back End Developer
# 4554                       Back End Developer( Node Js)
# 4556                                 Back End Developer
# 4559         Kafka Expert - Back End Developer (Remote)
# 4561  Web Applications (Back-end Developer) opening ...
# ...                                                 ...
# 5213                             Senior Azure Developer
# 5243                                 Open BMC Developer
# ...

# %%
d_de = a.get_group("data-engineer")
de = d_de[d_de.isnull().sum(axis = 1) == 0]
mean_de = de["Rating"].mean()
de1 = d_de[d_de.isnull().sum(axis = 1) == 1]
de_1 = de1.head(10)
add7 = (de,de_1)
r7 = pd.concat(add7)
df_de = r7.sort_index()
df_de['Rating'].fillna(value=mean_de, inplace=True)
df_de["Job_name"] = "Data Engineer"
df_de
# Out:
#       Unnamed: 0       Job_name  \
# 5318        5318  Data Engineer
# 5319        5319  Data Engineer
# 5336        5336  Data Engineer
# 5341        5341  Data Engineer
# 5342        5342  Data Engineer
# 5344        5344  Data Engineer
# 5347        5347  Data Engineer
# 5369        5369  Data Engineer
# 5385        5385  Data Engineer
# 5391        5391  Data Engineer
# 5392        5392  Data Engineer
# 5395        5395  Data Engineer
# 5396        5396  Data Engineer
# 5410        5410  Data Engineer
# 5433        5433  Data Engineer
# 5447        5447  Data Engineer
# 5532        5532  Data Engineer
# 5628        5628  Data Engineer
# 5637        5637  Data Engineer
# 5664        5664  Data Engineer
# 5669        5669  Data Engineer
# 5677        5677  Data Engineer
# 5717        5717  Data Engineer
# 5730        5730  Data Engineer
# 5738        5738  Data Engineer
# 5747        5747  Data Engineer
# 5808        5808  Data Engineer
# 5809        5809  Data Engineer
# ...

# %%
a_dfs = (df_sd,df_ds,df_da,df_se,df_fd,df_wd,df_bd,df_de)
df2 = pd.concat(a_dfs)

# %%
df2
# Out:
#       Unnamed: 0            Job_name  \
# 5              5  Software Developer
# 8              8  Software Developer
# 10            10  Software Developer
# 16            16  Software Developer
# 17            17  Software Developer
# ...          ...                 ...
# 5811        5811       Data Engineer
# 5846        5846       Data Engineer
# 5895        5895       Data Engineer
# 5905        5905       Data Engineer
# 5954        5954       Data Engineer
#
#                                                    Role  \
# 5     Software Developer/Software Engineer(B.E,B.Tec...
# 8                                    Software Developer
# 10                                   Software Developer
# 16                                   Software Developer
# 17    MNC Hiring | Fresher | Software Developer | Pa...
# ...                                                 ...
# 5811                                      Data Engineer
# 5846                                  Big Data Engineer
# ...

# %%
df2.round(1)
# Out:
#       Unnamed: 0            Job_name  \
# 5              5  Software Developer
# 8              8  Software Developer
# 10            10  Software Developer
# 16            16  Software Developer
# 17            17  Software Developer
# ...          ...                 ...
# 5811        5811       Data Engineer
# 5846        5846       Data Engineer
# 5895        5895       Data Engineer
# 5905        5905       Data Engineer
# 5954        5954       Data Engineer
#
#                                                    Role  \
# 5     Software Developer/Software Engineer(B.E,B.Tec...
# 8                                    Software Developer
# 10                                   Software Developer
# 16                                   Software Developer
# 17    MNC Hiring | Fresher | Software Developer | Pa...
# ...                                                 ...
# 5811                                      Data Engineer
# 5846                                  Big Data Engineer
# ...

# %%
df2[['min_salary (LPA)','max_salary (LPA)']] = df2['Salary'].str.split('-', expand = True)
df2.drop(['Salary'], inplace = True, axis = 1)                  # split salary as min and max columns and droping salary column

# %%
df2
# Out:
#       Unnamed: 0            Job_name  \
# 5              5  Software Developer
# 8              8  Software Developer
# 10            10  Software Developer
# 16            16  Software Developer
# 17            17  Software Developer
# ...          ...                 ...
# 5811        5811       Data Engineer
# 5846        5846       Data Engineer
# 5895        5895       Data Engineer
# 5905        5905       Data Engineer
# 5954        5954       Data Engineer
#
#                                                    Role  \
# 5     Software Developer/Software Engineer(B.E,B.Tec...
# 8                                    Software Developer
# 10                                   Software Developer
# 16                                   Software Developer
# 17    MNC Hiring | Fresher | Software Developer | Pa...
# ...                                                 ...
# 5811                                      Data Engineer
# 5846                                  Big Data Engineer
# ...

# %%
df2[['max_salary (LPA)',"1"]] = df2['max_salary (LPA)'].str.split(' L', expand = True)
df2.drop(['1'], inplace = True, axis = 1)
#

# %%
df2.drop(['Unnamed: 0'], inplace = True, axis = 1)

# %%
df2.tail(60)
# Out:
#                 Job_name                                               Role  \
# 5011  Back End Developer             Sr AWS (Backend) Developer For Top MNC
# 5013  Back End Developer                               Sr.Backend Developer
# 5015  Back End Developer                     Java Backend developer(Nodejs)
# 5019  Back End Developer                                    Unity Developer
# 5020  Back End Developer                                  SAP CPQ Developer
# 5030  Back End Developer                                     Java Developer
# 5103  Back End Developer         Java Developer (Spring Boot, Cloud, CI/CD)
# 5116  Back End Developer  Fresher Front-End / Back-End / Full Stack Deve...
# 5125  Back End Developer              C++ with Java & Spring boot developer
# 5129  Back End Developer  JAVA Microservices Developer Role-(microservic...
# 5135  Back End Developer  .NET Core Full stack Developer(Azure, Angular8)\n
# ...

# %%
df2.round(1)
# Out:
#                 Job_name                                               Role  \
# 5     Software Developer  Software Developer/Software Engineer(B.E,B.Tec...
# 8     Software Developer                                 Software Developer
# 10    Software Developer                                 Software Developer
# 16    Software Developer                                 Software Developer
# 17    Software Developer  MNC Hiring | Fresher | Software Developer | Pa...
# ...                  ...                                                ...
# 5811       Data Engineer                                      Data Engineer
# 5846       Data Engineer                                  Big Data Engineer
# 5895       Data Engineer                                      Data Engineer
# 5905       Data Engineer                                 Data Engineer- SAS
# 5954       Data Engineer                                      Data Engineer
#
# ...

# %%
b = df2.groupby("Location")
b.count().tail(30)
# Out:
#                                                     Job_name  Role  Company  \
# Location
# Noida, Hyderabad/Secunderabad, Pune, Chennai, B...         1     1        1
# Noida, Kolkata, Hyderabad/Secunderabad, Pune, C...         1     1        1
# Noida, Uttar Pradesh, Gurgaon/ Gurugram, Haryan...         1     1        1
# Pune                                                      22    22       22
# Pune(Baner)                                                1     1        1
# Pune, Bangalore/Bengaluru                                  1     1        1
# Pune, Chennai, Bangalore/Bengaluru                         3     3        3
# Pune, Chennai, Jaipur, Bangalore/Bengaluru                 1     1        1
# Pune, Maharashtra                                          1     1        1
# Raipur                                                     1     1        1
# Remote                                                    20    20       20
# ...

# %%
len(b.groups)
# Out:
# 158

# %%
b.get_group("Bangalore Rural, Mumbai (All Areas)")
# Out:
#            Job_name           Role           Company  Min_Experience  \
# 5677  Data Engineer  Data Engineer  Customer Centria             5.0
#
#       Max_Experiece                             Location  Rating  \
# 5677            6.0  Bangalore Rural, Mumbai (All Areas)     3.0
#
#      min_salary (LPA) max_salary (LPA)
# 5677               12               17

# %%
df2.replace("Bangalore Rural, Mumbai (All Areas)","Multiple Cities", inplace = True)
df2.replace("Bangalore/ Bengaluru, Karnataka","Bengaluru", inplace = True)
df2.replace("Bangalore/Bengaluru","Bengaluru", inplace = True)
df2.replace("Bangalore/Bengaluru(1st Phase JP Nagar)","Bengaluru", inplace = True)
df2.replace("Bangalore/Bengaluru(Old Madras Road)","Bengaluru", inplace = True)
df2.replace("Kolkata, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)	","Multiple Cities", inplace = True)
df2.replace("Noida, Haridwar","Delhi / NCR", inplace = True)
df2.replace("Hyderabad/Secunderabad, Hyderabad","Hyderabad", inplace = True)
df2.replace("Kolkata, West Bengal","Kolkata", inplace = True)
df2.replace("Temp. WFH - Gurgaon/ Gurugram, Haryana, Bangalore/Bengaluru, Mumbai (All Areas)","Temp. WFH - Multiple Cities", inplace = True)
# replacing the ",/-"

# %%
b.get_group("Pune(Baner)")
# Out:
#                 Job_name                                               Role  \
# 5116  Back End Developer  Fresher Front-End / Back-End / Full Stack Deve...
#
#                         Company  Min_Experience  Max_Experiece     Location  \
# 5116  Hummingbird Web Solutions             0.0            1.0  Pune(Baner)
#
#       Rating min_salary (LPA) max_salary (LPA)
# 5116     3.6              3.5             3.75

# %% [markdown]
# df2.replace("","", inplace = True)

# %%
df2 = df2.round(1)
df2.head(60)
# Out:
#                Job_name                                               Role  \
# 5    Software Developer  Software Developer/Software Engineer(B.E,B.Tec...
# 8    Software Developer                                 Software Developer
# 10   Software Developer                                 Software Developer
# 16   Software Developer                                 Software Developer
# 17   Software Developer  MNC Hiring | Fresher | Software Developer | Pa...
# 20   Software Developer  Software Engineer, developer / Programmer, 202...
# 21   Software Developer                                 Software Developer
# 22   Software Developer  Software Engineer, developer / Programmer, 202...
# 24   Software Developer                                 Software Developer
# 25   Software Developer                          Python Software Developer
# 27   Software Developer                                 Software Developer
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 403 entries, 5 to 5954
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Job_name          403 non-null    object
#  1   Role              403 non-null    object
#  2   Company           403 non-null    object
#  3   Min_Experience    403 non-null    float64
#  4   Max_Experiece     403 non-null    float64
#  5   Location          403 non-null    object
#  6   Rating            403 non-null    float64
#  7   min_salary (LPA)  403 non-null    object
#  8   max_salary (LPA)  397 non-null    object
# dtypes: float64(3), object(6)
# memory usage: 31.5+ KB

# %%
df2.isnull().any()
# Out:
# Job_name            False
# Role                False
# Company             False
# Min_Experience      False
# Max_Experiece       False
# Location            False
# Rating              False
# min_salary (LPA)    False
# max_salary (LPA)     True
# dtype: bool

# %%
df2[df2.isnull().sum(axis=1) > 0]
# Out:
#                 Job_name                                               Role  \
# 445   Software Developer  Software Developer (Power Platform) - Uganda -...
# 636   Software Developer                         Software Developer Trainee
# 2426   Software Engineer                                  Software Engineer
# 4981  Back End Developer                                     Rust Developer
# 5019  Back End Developer                                    Unity Developer
# 5020  Back End Developer                                  SAP CPQ Developer
#
#                   Company  Min_Experience  Max_Experiece  \
# 445   Trigyn Technologies             4.0            9.0
# 636      Smalsus Infolabs             0.0            1.0
# 2426        Tech Mahindra             1.0            3.0
# 4981        Tech Mahindra             6.0           11.0
# 5019        Tech Mahindra             4.0            9.0
# 5020        Tech Mahindra             4.0            4.0
#
# ...

# %%
df2.iloc[176]
# Out:
# Job_name            Software Engineer
# Role                Software Engineer
# Company                 Tech Mahindra
# Min_Experience                    1.0
# Max_Experiece                     3.0
# Location                       Mumbai
# Rating                            3.7
# min_salary (LPA)            3 Lacs PA
# max_salary (LPA)                 None
# Name: 2426, dtype: object

# %%
df2.iloc[176]
# Out:
# Job_name            Software Engineer
# Role                Software Engineer
# Company                 Tech Mahindra
# Min_Experience                    1.0
# Max_Experiece                     3.0
# Location                       Mumbai
# Rating                            3.7
# min_salary (LPA)            3 Lacs PA
# max_salary (LPA)                 None
# Name: 2426, dtype: object

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 403 entries, 5 to 5954
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Job_name          403 non-null    object
#  1   Role              403 non-null    object
#  2   Company           403 non-null    object
#  3   Min_Experience    403 non-null    float64
#  4   Max_Experiece     403 non-null    float64
#  5   Location          403 non-null    object
#  6   Rating            403 non-null    float64
#  7   min_salary (LPA)  403 non-null    object
#  8   max_salary (LPA)  397 non-null    object
# dtypes: float64(3), object(6)
# memory usage: 31.5+ KB

# %%
df2.isnull().sum()
# Out:
# Job_name            0
# Role                0
# Company             0
# Min_Experience      0
# Max_Experiece       0
# Location            0
# Rating              0
# min_salary (LPA)    0
# max_salary (LPA)    6
# dtype: int64

# %%
df2["min_salary (LPA)"] = df2["min_salary (LPA)"].astype(float)
df2.info()                                                     # changing salary column type from object to float

# %%
#df2["min_salary (LPA)"].mean()     # mean of min salary

# %%
df2["max_salary (LPA)"] = df2["max_salary (LPA)"].astype(float)

# %%
x1 = df2["min_salary (LPA)"].mean()/df2["max_salary (LPA)"].mean()        # difference b/w avg of min and avg of max salary
x1

# %%
print(5*x1+5)
print(3*x1+3)                      # max salary = min salary + min salary * x1

# %%
df2.to_csv("file1.csv")

# %%
df3 = pd.read_csv("file1.csv")
df3

# %%
df3.drop(['Unnamed: 0'], inplace = True, axis = 1)

# %%
df3

# %%
df3.describe()

# %%
df3

# %%
df3 = df3.rename(columns={'Max_Experiece': 'Maximum Experience', 'min_salary (LPA)': 'Minimum Salary in LPA','max_salary (LPA)': 'Maximum Salary in LPA'})
df3 = df3.rename(columns={'Min_Experience': 'Minimum Experience'})
df3

# %%
#df3.to_csv(r"C:\Users\saikiran\file1.csv")
